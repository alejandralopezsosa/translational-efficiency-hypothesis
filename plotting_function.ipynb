# %%
install.packages("ggplot2")
# Out:
# Warning message in readRDS(dest):
# "lzma decoder corrupt data"
# The downloaded binary packages are in
# 	/var/folders/46/mdzb67gx4279wbyw4nz_sm700000gn/T//RtmpjYe11B/downloaded_packages

# %%
library(ggplot2)
# Out:
# Warning message:
# "le package 'ggplot2' a 'et'e compil'e avec la version R 4.1.2"

# %%
data(iris)
head(iris)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
# build a plot with iris data and assign it to an object
p <- ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width, color = Species)) +
  geom_point() +
  theme_bw() +
  theme(legend.position = "none")

# print the plot
print(p)
# Out:
# plot without title

# %%
# source efficiency_model.ypynb file
efficiency_equation_df = read.csv(file = "/Users/ale/Documents/thesis_codon_bias/Testing_the_TEH/Rscripts/efficiency_equation_df_for_plotting.csv", header = TRUE)

# store data by strain in new data frames
b21_efficiency_equation_df <- subset(efficiency_equation_df, strain == "BL21DE3")
k12_efficiency_equation_df <- subset(efficiency_equation_df, strain == "K12")

# %%
b21_efficiency_equation_df
# Out:
#     sequence_name          strain  value    predicted_level
# 113 V015-wildtype          BL21DE3 16486.75 17098.38
# 114 V015-wildtype          BL21DE3 16621.75 17098.38
# 115 V015-wildtype          BL21DE3 17863.75 17098.38
# 116 V015-wildtype          BL21DE3 13851.75 17098.38
# 117 V015-wildtype          BL21DE3 19477.00 17098.38
# 118 V015-wildtype          BL21DE3 19002.00 17098.38
# 119 V015-wildtype          BL21DE3 19599.00 17098.38
# 120 V015-wildtype          BL21DE3 13885.00 17098.38
# 121 V016-AnaCoda           BL21DE3 32716.75 12168.92
# 122 V016-AnaCoda           BL21DE3 31710.75 12168.92
# 123 V016-AnaCoda           BL21DE3 30605.75 12168.92
# 124 V016-AnaCoda           BL21DE3 34179.75 12168.92
# 125 V016-AnaCoda           BL21DE3 34453.00 12168.92
# 126 V016-AnaCoda           BL21DE3 35672.00 12168.92
# 127 V016-AnaCoda           BL21DE3 34050.00 12168.92
# 128 V016-AnaCoda           BL21DE3 32072.00 12168.92
# 129 V017-GeneGA            BL21DE3 31330.75 11966.98
# ...

# %%
efficiency_model_df = read.csv(file = "/Users/ale/Documents/thesis_codon_bias/Testing_the_TEH/Rscripts/efficiency_model_df_for_plotting.csv", header = TRUE)

# store data by strain in new data frames
b21_efficiency_model_df <- subset(efficiency_model_df, strain == "BL21DE3")
k12_efficiency_model_df <- subset(efficiency_model_df, strain == "K12")

# %%
k12_efficiency_model_df
# Out:
#     sequence_name            strain value   predicted_level
# 1   V015-wildtype            K12    14853.5 14075.00
# 2   V015-wildtype            K12    14101.5 14075.00
# 3   V015-wildtype            K12    15070.5 14075.00
# 4   V015-wildtype            K12    14050.5 14075.00
# 5   V015-wildtype            K12    14740.0 14075.00
# 6   V015-wildtype            K12    14743.0 14075.00
# 7   V015-wildtype            K12    13430.0 14075.00
# 8   V015-wildtype            K12    11611.0 14075.00
# 9   V016-AnaCoda             K12    21446.5 19979.08
# 10  V016-AnaCoda             K12    21939.5 19979.08
# 11  V016-AnaCoda             K12    24331.5 19979.08
# 12  V016-AnaCoda             K12    20637.5 19979.08
# 13  V016-AnaCoda             K12    20591.0 19979.08
# 14  V016-AnaCoda             K12    20112.0 19979.08
# 15  V016-AnaCoda             K12    18782.0 19979.08
# 16  V016-AnaCoda             K12    17608.0 19979.08
# 17  V018-JCAT                K12    28054.5 20285.20
# ...

# %%
accuracy_model_phi_df = read.csv(file = "/Users/ale/Documents/thesis_codon_bias/Testing_the_TEH/Rscripts/accuracy_model_phi_df_for_plotting.csv", header = TRUE)

# store data by strain in new data frames
b21_accuracy_model_phi_df <- subset(accuracy_model_phi_df, strain == "BL21DE3")
k12_accuracy_model_phi_df <- subset(accuracy_model_phi_df, strain == "K12")

# %%
b21_accuracy_model_phi_df
# Out:
#     sequence_name          strain  value    predicted_level
# 1   V015-wildtype          BL21DE3 16486.75 17098.38
# 2   V015-wildtype          BL21DE3 16621.75 17098.38
# 3   V015-wildtype          BL21DE3 17863.75 17098.38
# 4   V015-wildtype          BL21DE3 13851.75 17098.38
# 5   V015-wildtype          BL21DE3 19477.00 17098.38
# 6   V015-wildtype          BL21DE3 19002.00 17098.38
# 7   V015-wildtype          BL21DE3 19599.00 17098.38
# 8   V015-wildtype          BL21DE3 13885.00 17098.38
# 17  V016-AnaCoda           BL21DE3 32716.75 12391.74
# 18  V016-AnaCoda           BL21DE3 31710.75 12391.74
# 19  V016-AnaCoda           BL21DE3 30605.75 12391.74
# 20  V016-AnaCoda           BL21DE3 34179.75 12391.74
# 21  V016-AnaCoda           BL21DE3 34453.00 12391.74
# 22  V016-AnaCoda           BL21DE3 35672.00 12391.74
# 23  V016-AnaCoda           BL21DE3 34050.00 12391.74
# 24  V016-AnaCoda           BL21DE3 32072.00 12391.74
# 33  V017-GeneGA            BL21DE3 31330.75 12194.62
# ...

# %%
accuracy_model_prot_df = read.csv(file = "/Users/ale/Documents/thesis_codon_bias/Testing_the_TEH/Rscripts/accuracy_model_prot_df_for_plotting.csv", header = TRUE)

# store data by strain in new data frames
b21_accuracy_model_prot_df <- subset(accuracy_model_prot_df, strain == "BL21DE3")
k12_accuracy_model_prot_df <- subset(accuracy_model_prot_df, strain == "K12")

# %%
k12_accuracy_model_prot_df
# Out:
#     sequence_name            strain value   predicted_level
# 9   V015-wildtype            K12    14853.5 14075.00
# 10  V015-wildtype            K12    14101.5 14075.00
# 11  V015-wildtype            K12    15070.5 14075.00
# 12  V015-wildtype            K12    14050.5 14075.00
# 13  V015-wildtype            K12    14740.0 14075.00
# 14  V015-wildtype            K12    14743.0 14075.00
# 15  V015-wildtype            K12    13430.0 14075.00
# 16  V015-wildtype            K12    11611.0 14075.00
# 25  V016-AnaCoda             K12    21446.5 14479.48
# 26  V016-AnaCoda             K12    21939.5 14479.48
# 27  V016-AnaCoda             K12    24331.5 14479.48
# 28  V016-AnaCoda             K12    20637.5 14479.48
# 29  V016-AnaCoda             K12    20591.0 14479.48
# 30  V016-AnaCoda             K12    20112.0 14479.48
# 31  V016-AnaCoda             K12    18782.0 14479.48
# 32  V016-AnaCoda             K12    17608.0 14479.48
# 49  V018-JCAT                K12    28054.5 14493.80
# ...

# %%
# build a plot with efficiency_equation_df and add a regression line. Include only strain == "K12"
p <- ggplot(efficiency_equation_df, aes(x = predicted_level, y = value, color = strain)) +
  geom_point() +
  geom_smooth(method = "lm", se = FALSE) +
  theme_bw() +
  theme(legend.position = "none")


# print the plot
print(p)
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
# build a basic scatter plot with efficiency_model_df
ggplot(efficiency_model_df, aes(predicted_level, value)) +
geom_point()
# Out:
# plot without title

# %%
ggplot(b21_efficiency_equation_df, aes(predicted_level, value, colour=sequence_name)) +
geom_point(shape=2) +
geom_smooth(method=lm)
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title
